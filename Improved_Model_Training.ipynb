# %%
import os
import pathlib

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import models
from IPython import display

import pandas as pd

# Set the seed value for experiment reproducibility.
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
DATASET_PATH = 'data/mini_speech_commands'

data_dir = pathlib.Path(DATASET_PATH)
if not data_dir.exists():
  tf.keras.utils.get_file(
      'mini_speech_commands.zip',
      origin="http://storage.googleapis.com/download.tensorflow.org/data/mini_speech_commands.zip",
      extract=True,
      cache_dir='.', cache_subdir='data')

# %%
commands = np.array(tf.io.gfile.listdir(str(data_dir)))
commands = commands[(commands != 'README.md') & (commands != '.DS_Store')]
print('Commands:', commands)
# Out:
# Commands: ['down' 'go' 'left' 'no' 'right' 'stop' 'up' 'yes']

# %%
train_ds, val_ds = tf.keras.utils.audio_dataset_from_directory(
    directory=data_dir,
    batch_size=64,
    validation_split=0.2,
    seed=0,
    output_sequence_length=16000,
    subset='both')

label_names = np.array(train_ds.class_names)
print("label names:", label_names)
# Out:
# Found 8000 files belonging to 8 classes.
# Using 6400 files for training.
# Using 1600 files for validation.
# label names: ['down' 'go' 'left' 'no' 'right' 'stop' 'up' 'yes']

# %%
# ---- IMPROVE ----#
from IPython.display import clear_output
ind = 0
new_train_ds = np.array((6400, 16001, 1))
for x in train_ds:
    for sm in x[0]:
        print(sm)
    for smn in x[1]:
        new_train_ds[ind][16001] = smn
# Out:
# tf.Tensor(
# [[ 0.00756836]
#  [ 0.00515747]
#  [ 0.00357056]
#  ...
#  [-0.01681519]
#  [-0.01278687]
#  [-0.01358032]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[0.0007019 ]
#  [0.00112915]
#  [0.00100708]
#  ...
#  [0.        ]
#  [0.        ]
#  [0.        ]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-0.00112915]
#  [-0.00100708]
#  [-0.00210571]
#  ...
#  [-0.0015564 ]
#  [-0.00140381]
#  [-0.00247192]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-3.0517578e-05]
#  [-9.1552734e-05]
#  [-1.2207031e-04]
#  ...
#  [ 2.1362305e-04]
#  [ 2.4414062e-04]
#  [ 1.5258789e-04]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-0.00131226]
#  [-0.00213623]
#  [-0.00231934]
#  ...
#  [-0.00079346]
#  [-0.0012207 ]
#  [-0.00170898]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[ 0.0010376 ]
#  [ 0.00097656]
#  [ 0.00094604]
#  ...
#  [-0.00183105]
#  [-0.00158691]
#  [-0.00152588]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[0.00061035]
#  [0.00079346]
#  [0.00076294]
#  ...
#  [0.00091553]
#  [0.0010376 ]
#  [0.00085449]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-0.00131226]
#  [-0.00131226]
#  [-0.00137329]
#  ...
#  [-0.00244141]
#  [-0.00189209]
#  [-0.00152588]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[ 0.00033569]
#  [ 0.00061035]
#  [ 0.00085449]
#  ...
#  [-0.00115967]
#  [-0.0017395 ]
#  [-0.00131226]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-7.3242188e-04]
#  [-3.0517578e-05]
#  [ 1.2817383e-03]
#  ...
#  [ 1.3336182e-02]
#  [ 1.4984131e-02]
#  [ 1.6235352e-02]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[ 0.00033569]
#  [ 0.00088501]
#  [ 0.00076294]
#  ...
#  [-0.00036621]
#  [-0.00027466]
#  [-0.00030518]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[ 1.2207031e-04]
#  [ 0.0000000e+00]
#  [ 3.0517578e-05]
#  ...
#  [ 9.1552734e-05]
#  [ 1.2207031e-04]
#  [-2.1362305e-04]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[0.        ]
#  [0.00024414]
#  [0.00021362]
#  ...
#  [0.00042725]
#  [0.00057983]
#  [0.00045776]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-0.00714111]
#  [-0.01260376]
#  [-0.01098633]
#  ...
#  [ 0.00595093]
#  [ 0.01550293]
#  [ 0.01486206]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[ 0.00167847]
#  [ 0.00088501]
#  [ 0.0010376 ]
#  ...
#  [-0.00546265]
#  [-0.00537109]
#  [-0.00692749]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[ 6.1035156e-05]
#  [ 6.1035156e-05]
#  [ 6.1035156e-05]
#  ...
#  [-9.1552734e-05]
#  [-9.1552734e-05]
#  [-9.1552734e-05]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-3.0517578e-05]
#  [-6.1035156e-05]
#  [-6.1035156e-05]
#  ...
#  [-4.1503906e-03]
#  [-5.1879883e-03]
#  [-6.1950684e-03]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[ 3.0517578e-05]
#  [-9.1552734e-05]
#  [-3.6621094e-04]
#  ...
#  [-7.0190430e-04]
#  [-6.4086914e-04]
#  [-5.1879883e-04]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[ 3.0517578e-05]
#  [-6.1035156e-05]
#  [-1.5258789e-04]
#  ...
#  [-9.1552734e-05]
#  [-9.1552734e-05]
#  [-6.1035156e-05]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-0.00430298]
#  [-0.00448608]
#  [-0.00402832]
#  ...
#  [-0.00424194]
#  [-0.00445557]
#  [-0.00494385]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[ 2.7465820e-04]
#  [ 3.0517578e-04]
#  [-3.3569336e-04]
#  ...
#  [-3.0517578e-05]
#  [-3.3569336e-04]
#  [-7.0190430e-04]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[0.00024414]
#  [0.00045776]
#  [0.0007019 ]
#  ...
#  [0.00073242]
#  [0.00073242]
#  [0.00073242]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[0.00158691]
#  [0.00183105]
#  [0.0017395 ]
#  ...
#  [0.00177002]
#  [0.0017395 ]
#  [0.00189209]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-0.00018311]
#  [-0.0005188 ]
#  [-0.00045776]
#  ...
#  [ 0.00021362]
#  [ 0.00021362]
#  [ 0.00030518]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[ 0.00054932]
#  [ 0.00149536]
#  [ 0.00158691]
#  ...
#  [-0.00085449]
#  [-0.00100708]
#  [-0.00094604]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-0.00112915]
#  [-0.00085449]
#  [-0.00112915]
#  ...
#  [-0.0010376 ]
#  [-0.00109863]
#  [-0.0007019 ]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-0.15197754]
#  [-0.25109863]
#  [-0.21850586]
#  ...
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[ 3.0517578e-05]
#  [ 9.1552734e-05]
#  [ 1.2207031e-04]
#  ...
#  [-1.8310547e-04]
#  [-3.3569336e-04]
#  [-5.1879883e-04]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-9.1552734e-05]
#  [ 3.6621094e-04]
#  [ 8.8500977e-04]
#  ...
#  [-1.4343262e-03]
#  [-9.7656250e-04]
#  [-1.0375977e-03]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[0.        ]
#  [0.00018311]
#  [0.00030518]
#  ...
#  [0.        ]
#  [0.        ]
#  [0.        ]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[ 0.00323486]
#  [ 0.00204468]
#  [ 0.00140381]
#  ...
#  [-0.00836182]
#  [-0.00790405]
#  [-0.00888062]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-0.01104736]
#  [-0.00994873]
#  [-0.0093689 ]
#  ...
#  [ 0.0105896 ]
#  [ 0.01095581]
#  [ 0.01193237]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[0.00082397]
#  [0.00088501]
#  [0.00088501]
#  ...
#  [0.00094604]
#  [0.00094604]
#  [0.00088501]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[ 0.00241089]
#  [ 0.00244141]
#  [ 0.00369263]
#  ...
#  [-0.0017395 ]
#  [-0.00204468]
#  [-0.00354004]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-0.01702881]
#  [-0.01751709]
#  [-0.01745605]
#  ...
#  [-0.01672363]
#  [-0.01602173]
#  [-0.01974487]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[0.0000000e+00]
#  [6.1035156e-05]
#  [9.1552734e-05]
#  ...
#  [0.0000000e+00]
#  [9.1552734e-05]
#  [6.1035156e-05]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-0.00012207]
#  [-0.00015259]
#  [-0.00015259]
#  ...
#  [ 0.00030518]
#  [-0.00033569]
#  [-0.00054932]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[ 5.7983398e-04]
#  [ 7.9345703e-04]
#  [ 9.7656250e-04]
#  ...
#  [-1.0986328e-03]
#  [-6.7138672e-04]
#  [-9.1552734e-05]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[0.        ]
#  [0.00021362]
#  [0.00042725]
#  ...
#  [0.00018311]
#  [0.00039673]
#  [0.00021362]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[ 3.0517578e-05]
#  [ 2.1362305e-04]
#  [ 9.4604492e-04]
#  ...
#  [-3.2043457e-03]
#  [-3.0822754e-03]
#  [-3.0517578e-03]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[0.0000000e+00]
#  [0.0000000e+00]
#  [0.0000000e+00]
#  ...
#  [0.0000000e+00]
#  [3.0517578e-05]
#  [3.0517578e-05]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[0.03579712]
#  [0.04086304]
#  [0.04797363]
#  ...
#  [0.03808594]
#  [0.03753662]
#  [0.0380249 ]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-3.0517578e-05]
#  [-3.0517578e-05]
#  [ 3.0517578e-05]
#  ...
#  [ 2.1362305e-04]
#  [ 2.1362305e-04]
#  [ 4.2724609e-04]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[0.00198364]
#  [0.00228882]
#  [0.00222778]
#  ...
#  [0.00213623]
#  [0.00204468]
#  [0.00204468]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[ 0.00411987]
#  [ 0.00631714]
#  [ 0.00750732]
#  ...
#  [-0.00714111]
#  [-0.00531006]
#  [-0.00473022]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-0.00894165]
#  [-0.01025391]
#  [-0.00894165]
#  ...
#  [-0.01501465]
#  [-0.01254272]
#  [-0.00900269]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-0.00280762]
#  [-0.00238037]
#  [-0.00265503]
#  ...
#  [-0.00363159]
#  [-0.00341797]
#  [-0.00411987]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[0.00628662]
#  [0.00900269]
#  [0.00701904]
#  ...
#  [0.0055542 ]
#  [0.00634766]
#  [0.00750732]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-0.00027466]
#  [-0.00067139]
#  [-0.00164795]
#  ...
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-0.18728638]
#  [-0.21063232]
#  [-0.19171143]
#  ...
#  [ 0.19613647]
#  [ 0.2046814 ]
#  [ 0.20733643]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-0.00067139]
#  [-0.00076294]
#  [-0.00061035]
#  ...
#  [ 0.00027466]
#  [-0.00018311]
#  [-0.00091553]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-0.00152588]
#  [-0.00210571]
#  [-0.00094604]
#  ...
#  [ 0.00323486]
#  [ 0.00305176]
#  [ 0.0022583 ]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-0.00802612]
#  [-0.00744629]
#  [-0.0093689 ]
#  ...
#  [-0.01449585]
#  [-0.01217651]
#  [-0.01037598]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-6.1035156e-05]
#  [-1.4953613e-03]
#  [ 2.1362305e-04]
#  ...
#  [ 0.0000000e+00]
#  [ 0.0000000e+00]
#  [ 0.0000000e+00]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[0.00204468]
#  [0.00427246]
#  [0.00564575]
#  ...
#  [0.00216675]
#  [0.00216675]
#  [0.00134277]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[ 0.        ]
#  [ 0.0007019 ]
#  [ 0.00048828]
#  ...
#  [-0.00036621]
#  [-0.00021362]
#  [-0.00024414]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-0.00323486]
#  [-0.00396729]
#  [-0.00527954]
#  ...
#  [-0.00473022]
#  [-0.00485229]
#  [-0.0038147 ]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[3.0517578e-05]
#  [9.1552734e-05]
#  [9.1552734e-05]
#  ...
#  [2.1362305e-03]
#  [2.3803711e-03]
#  [2.6855469e-03]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-0.00018311]
#  [-0.00024414]
#  [-0.00015259]
#  ...
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[ 0.00064087]
#  [ 0.00067139]
#  [ 0.00076294]
#  ...
#  [-0.00119019]
#  [-0.00082397]
#  [-0.00079346]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[0.00073242]
#  [0.00112915]
#  [0.00119019]
#  ...
#  [0.00131226]
#  [0.00109863]
#  [0.0012207 ]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-0.00152588]
#  [-0.00323486]
#  [-0.00253296]
#  ...
#  [ 0.00128174]
#  [ 0.0020752 ]
#  [ 0.00308228]], shape=(16000, 1), dtype=float32)
# tf.Tensor(
# [[-0.00338745]
#  [-0.00500488]
#  [-0.00534058]
#  ...
#  [-0.00585938]
#  [-0.00588989]
#  [-0.00564575]], shape=(16000, 1), dtype=float32)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 9
#       7     print(sm)
#       8 for smn in x[1]:
# ----> 9     new_train_ds[ind][16001] = smn
#
# TypeError: 'numpy.int32' object does not support item assignment

# %%
# Commands: ['down' 'go' 'left' 'no' 'right' 'stop' 'up' 'yes']
# indeces : [ 0      1    2      3    4       5      6    7]
# so we want to remove 1 3 and 7
for i in range(64*16000, 64*16000+64):
    if(new_train_ds[i] in {1, 3, 7}):
        np.delete(new_train_ds)
# Out:
# 1.0
# 1.0
# 1.0
# 7.0
# 7.0
# 3.0
# 3.0
# 3.0
# 1.0
# 3.0
# 3.0
# 7.0
# 7.0
# 3.0
# 3.0
# 7.0
# 1.0
# 3.0
# 1.0
# 1.0
